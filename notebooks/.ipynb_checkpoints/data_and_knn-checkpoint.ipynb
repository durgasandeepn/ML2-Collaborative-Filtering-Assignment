# %% [markdown]
# # Programming Assignment 1: Recommender System
# ### Coure: CS373
# #### Developer 1: Jalin A. Brown
# #### Developer 2: Sandeep Durga
# #### File: 01_data_and_knn.ipynb
#
# ### Part One: Data Setup and User-Based Collaborative Filtering
#
# 1. Load and preprocess data:
# - Create user-item rating matrix.
# - Analyze sparsity: calculate percentage of missing ratings:
#  - - Sparsity = (Number of Missing Ratings / Total Possible Ratings) × 100
#
# 2. Build K-Nearest Neighbors recommender:
# - Find k most similar users for any target user (test different values of k)
# - Only consider users with positive similarity scores
# - Predict ratings using weighted average
# - Handle edge case

# %%
# Import libraries needed for the project
import numpy as np                                     # math
import pandas as pd                                    # user-item matrix
from sklearn.metrics.pairwise import cosine_similarity # pairwise similarity between users

# %% [markdown]
# ### 1. Load and preprocess data:

# %% [markdown]
# #### Create user-item rating matrix

# %%
# Import the MovieLens 100k training and test data sets
# Currently using the first fold split of data of user.base computed as u1_base and u1_test
u1_base_mat = pd.read_csv("../data/u1.base", names=["user_id","item_id","rating","timestamp"], sep="\t", )
u1_test_mat = pd.read_csv("../data/u1.test", names=["user_id","item_id","rating","timestamp"], sep="\t")
print(u1_base_mat.head())
print(f"\nTraining data shape: {u1_base_mat.shape}\n")


print(u1_test_mat.head())
print(f"\nTest data shape: {u1_test_mat.shape}\n")
# Out:
#    user_id  item_id  rating  timestamp
# 0        1        1       5  874965758
# 1        1        2       3  876893171
# 2        1        3       4  878542960
# 3        1        4       3  876893119
# 4        1        5       3  889751712
#
# Training data shape: (80000, 4)
#
#    user_id  item_id  rating  timestamp
# 0        1        6       5  887431973
# 1        1       10       3  875693118
# 2        1       12       5  878542960
# 3        1       14       5  874965706
# 4        1       17       3  875073198
#
# Test data shape: (20000, 4)

# %%
# Create user-item matrix (excluding possible duplicates or non integers)
users = u1_base_mat["user_id"].astype(int).unique()
items = u1_base_mat["item_id"].astype(int).unique()
user_item_training_matrix = pd.DataFrame(np.nan, index=users, columns=items)

# Fill cells with ratings
for row in u1_base_mat.itertuples(index = False):
    user_item_training_matrix.loc[row.user_id, row.item_id] = row.rating

user_item_training_matrix
# Out:
#      1     2     3     4     5     7     8     9     11    13    ...  1674  \
# 1     5.0   3.0   4.0   3.0   3.0   4.0   1.0   5.0   2.0   5.0  ...   NaN
# 2     4.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 3     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 4     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   4.0   NaN  ...   NaN
# 5     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 939   NaN   NaN   NaN   NaN   NaN   NaN   NaN   5.0   NaN   NaN  ...   NaN
# 940   NaN   NaN   NaN   2.0   NaN   4.0   5.0   3.0   NaN   NaN  ...   NaN
# 941   5.0   NaN   NaN   NaN   NaN   4.0   NaN   NaN   NaN   NaN  ...   NaN
# 942   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 943   NaN   5.0   NaN   NaN   NaN   NaN   NaN   3.0   4.0   NaN  ...   NaN
#
#      1675  1676  1677  1678  1679  1680  907   1681  1682
# 1     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 939   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 940   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 941   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 942   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 943   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [943 rows x 1650 columns]

# %% [markdown]
# #### Analyze Sparsity

# %%
# Create the user-item matrix
user_count = user_item_training_matrix.shape[0]
item_count = user_item_training_matrix.shape[1]
mat_size = user_count * item_count
present = user_item_training_matrix.count().sum()
missing = mat_size - present
sparsity = (missing / mat_size) * 100

print(f"sparsity: {sparsity:.2f}%")
# Out:
# sparsity: 94.86%

# %% [markdown]
# ### 2. Build KNN Recommender:

# %% [markdown]
# #### This next module covers:
# - Full similarity space with Nan set to 0
# - Only keep users with cosine_similarity > 0 (positive relationship)
#
# Note:
# - Positive similarity (0.0, 1.0] indicates similar taste
# - Negative similarity [-1, 0.0) indicates opposite taste
# - Each index [i,j] is the cosine similarity score between user i and j

# %%
# Fill missing ratings with 0 for cosine similarity
ui_training_mat_filled = user_item_training_matrix.fillna(0)

# Compute cosine similarity between all users
cosine_sim_mat = cosine_similarity(ui_training_mat_filled)
cosine_sim_matrix = pd.DataFrame(cosine_sim_mat, index=user_item_training_matrix.index, columns=user_item_training_matrix.index)

cosine_sim_matrix.head()
# Out:
#         1         2         3         4         5         6         7    \
# 1  1.000000  0.097021  0.052469  0.021162  0.193545  0.290114  0.200438
# 2  0.097021  1.000000  0.051348  0.084426  0.015516  0.187717  0.074479
# 3  0.052469  0.051348  1.000000  0.145660  0.037180  0.084526  0.015718
# 4  0.021162  0.084426  0.145660  1.000000  0.017291  0.000000  0.037566
# 5  0.193545  0.015516  0.037180  0.017291  1.000000  0.158552  0.170890
#
#         8         9         10   ...       934       935       936       937  \
# 1  0.097786  0.060791  0.200926  ...  0.252187  0.090728  0.216186  0.139478
# 2  0.023262  0.108167  0.078176  ...  0.083045  0.298811  0.308608  0.403810
# 3  0.086400  0.000000  0.030909  ...  0.041330  0.036956  0.135750  0.063940
# 4  0.046087  0.000000  0.023232  ...  0.014238  0.047742  0.127305  0.118947
# 5  0.157488  0.053846  0.089508  ...  0.284295  0.074215  0.086345  0.063759
#
#         938       939       940       941       942       943
# 1  0.156937  0.095265  0.222958  0.158151  0.133090  0.252778
# 2  0.282896  0.213233  0.189257  0.132806  0.126597  0.101784
# 3  0.102082  0.034064  0.133720  0.083537  0.081230  0.019676
# 4  0.089016  0.039116  0.120521  0.135669  0.125925  0.035586
# 5  0.126358  0.068145  0.198118  0.142141  0.150000  0.239803
#
# [5 rows x 943 columns]

# %% [markdown]
# #### Find K most similar users for any target user
#
# (positive similarity only, testing different values of K)
#
# using user 1 as an example

# %%
# Select the target user
current_user = 1

# Select a value of K
K_values = [1, 3, 5, 7, 10]

# Extract similarities between this user and all other users
similarities_to_others = cosine_sim_matrix[current_user].copy()
similarities_to_others = similarities_to_others.drop(index=current_user)
pos_sim = similarities_to_others[similarities_to_others > 0.0].sort_values(ascending=False)

print(f"Top similar users for user {current_user} with varying K:\n")
for k in K_values:
    top_k = pos_sim.head(k)
    print(f"K = {k}:")
    print(top_k)
    print("-"*40)

# %% [markdown]
# ###  Predict ratings using weighted average
# Using the weighted similarity formula:
# - Select target user (u) and a target item (i) for which the user has not rated yet
# - Gather the K most similar neighbor users who have rated the target item
# - Compute the weighted average of their ratings using similarity as weight
# - If no neighbor has rated that item, handle as an edge case

# %%
# Check Target user for an unrated target item
user_item_training_matrix

# %%
# Choose target user and unrated target item
target_user = 2
target_item = 2
k_value = 5

# Gather k most similar neighbors who have rated the target item
pos_sim = cosine_sim_matrix[current_user].drop(index=current_user)
pos_sim = pos_sim[pos_sim > 0.0].sort_values(ascending=False)
top_k = pos_sim.head(k_value)

numerator = 0.0
denominator = 0.0

for neighbor, sim in top_k.items():
    neighbor_rating = user_item_training_matrix.loc[neighbor, target_item]
    if not np.isnan(neighbor_rating):
        numerator += neighbor_rating * sim
        denominator += abs(sim)
if denominator == 0:
    print(f"No similar users for user {target_user} rated {target_item}.")
    predicted_rating = np.nan
else:
    predicted_rating = numerator / denominator
    print(f"Using K value {k_value}, the predicted rating for user {target_user} on item {target_item} is {predicted_rating:.2f}.")

# %% [markdown]
# #### ^ All code up to this point written by Jalin A. Brown ^
